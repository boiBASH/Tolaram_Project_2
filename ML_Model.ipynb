# %% [markdown]
# <a href="https://colab.research.google.com/github/boiBASH/Tolaram_Project_2/blob/main/ML_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder


# Load and clean data
df = pd.read_csv('/content/drive/MyDrive/Data Analysis - Sample File.csv')
df = df.rename(columns={
    'Delivered_date': 'delivered_date',
    'Delivered Qty': 'delivered_qty',
    'Redistribution Value': 'spend'
})
# Updated datetime parsing with dayfirst=True
df['delivered_date'] = pd.to_datetime(df['delivered_date'], errors='coerce', dayfirst=True)
df['spend'] = df['spend'].str.replace(',', '').astype(float)
df = df[df['delivered_qty'] > 0].sort_values(['Customer_Phone', 'SKU_Code', 'delivered_date'])

# Feature engineering
df['prev_date'] = df.groupby(['Customer_Phone', 'SKU_Code'])['delivered_date'].shift(1)
df['recency_days'] = (df['delivered_date'] - df['prev_date']).dt.days.fillna(-1)
df['cum_freq'] = df.groupby(['Customer_Phone', 'SKU_Code']).cumcount()
df['cum_spend'] = df.groupby(['Customer_Phone', 'SKU_Code'])['spend'].cumsum() - df['spend']
df['avg_spend_past'] = df['cum_spend'] / df['cum_freq'].replace(0, 1)
df['cum_qty'] = df.groupby(['Customer_Phone', 'SKU_Code'])['delivered_qty'].cumsum() - df['delivered_qty']
df['avg_qty_past'] = df['cum_qty'] / df['cum_freq'].replace(0, 1)

# Compute targets
df['next_date'] = df.groupby(['Customer_Phone', 'SKU_Code'])['delivered_date'].shift(-1)
df['next_days'] = (df['next_date'] - df['delivered_date']).dt.days
df['next_spend'] = df.groupby(['Customer_Phone', 'SKU_Code'])['spend'].shift(-1)
df['next_qty'] = df.groupby(['Customer_Phone', 'SKU_Code'])['delivered_qty'].shift(-1)
df['y_buy'] = df['next_days'].notnull().astype(int)

# Encode SKU
le_sku = LabelEncoder().fit(df['SKU_Code'])
df['sku_enc'] = le_sku.transform(df['SKU_Code'])

# Define features
features = ['recency_days', 'cum_freq', 'avg_spend_past', 'avg_qty_past', 'sku_enc']

# Train classifier
X_clf = df[features]
y_clf = df['y_buy']
Xc_train, Xc_test, yc_train, yc_test = train_test_split(X_clf, y_clf, test_size=0.2, random_state=42)
clf = RandomForestClassifier(n_estimators=20, random_state=42).fit(Xc_train, yc_train)

# Train regressors on positive instances
df_reg = df[df['y_buy'] == 1].dropna(subset=['next_days', 'next_spend', 'next_qty'])
X_reg = df_reg[features]
y_days = df_reg['next_days']
y_spend = df_reg['next_spend']
y_qty = df_reg['next_qty']

reg_days = RandomForestRegressor(n_estimators=20, random_state=42).fit(X_reg, y_days)
reg_spend = RandomForestRegressor(n_estimators=20, random_state=42).fit(X_reg, y_spend)
reg_qty = RandomForestRegressor(n_estimators=20, random_state=42).fit(X_reg, y_qty)

# Predict on latest snapshot
latest = df.groupby(['Customer_Phone', 'SKU_Code']).last().reset_index()
latest['last_purchase_date'] = latest['delivered_date']
latest['recency_days'] = (pd.Timestamp.now() - latest['delivered_date']).dt.days
latest['sku_enc'] = le_sku.transform(latest['SKU_Code'])
latest['cum_freq'] = latest['cum_freq']
latest['avg_spend_past'] = latest['avg_spend_past']
latest['avg_qty_past'] = latest['avg_qty_past']

X_pred = latest[features]
latest['probability'] = clf.predict_proba(X_pred)[:, 1]
latest['pred_days'] = reg_days.predict(X_pred)
latest['pred_next_date'] = latest['last_purchase_date'] + pd.to_timedelta(latest['pred_days'], unit='D')
latest['pred_spend'] = reg_spend.predict(X_pred)
latest['pred_qty'] = reg_qty.predict(X_pred)

# Extract top-3 SKUs per customer based on true probabilities
results = (latest.sort_values(['Customer_Phone', 'probability'], ascending=[True, False])
                  .groupby('Customer_Phone').head(3).reset_index(drop=True))

# Display interactive results
pred_df = results[['Customer_Phone', 'SKU_Code', 'last_purchase_date',
                   'pred_next_date', 'pred_spend', 'pred_qty', 'probability']]
pred_df
# Out:
# <ipython-input-17-ea4517c3a0c5>:10: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Data Analysis - Sample File.csv')
#        Customer_Phone  SKU_Code last_purchase_date  \
# 0          7010009941  10002871         2024-11-28
# 1          7010009941  10002849         2024-10-03
# 2          7010009941  10002857         2025-01-02
# 3          7010147753  10002957         2024-11-28
# 4          7010147753  10002835         2024-09-09
# ...               ...       ...                ...
# 11382      9167401267  10003376         2025-01-07
# 11383      9167401267  10002861         2024-10-14
# 11384      9169810564  10000533         2024-11-21
# 11385      9169810564  10002844         2024-12-19
# 11386      9169810564  10002843         2024-12-19
#
#                      pred_next_date     pred_spend  pred_qty  probability
# 0     2024-12-14 14:43:34.718568473   20050.000000  1.023395     0.100000
# 1     2024-10-12 07:12:00.000000000   20607.500000  1.000000     0.000000
# 2     2025-01-23 22:48:00.000000000   24190.000000  1.100000     0.000000
# 3     2024-12-13 16:37:41.149746635  183629.656963  1.617399     0.304423
# 4     2024-10-08 04:18:16.049154156   23242.500000  1.159429     0.251098
# ...                             ...            ...       ...          ...
# 11382 2025-01-31 03:24:24.302564821   19850.000000  1.122391     0.273278
# 11383 2024-10-30 01:06:11.361857771   20000.000000  1.020956     0.173211
# 11384 2024-12-20 14:35:09.733016040   90317.778957  5.902993     0.428003
# 11385 2025-01-09 21:47:19.415802937   24130.000000  1.310417     0.374679
# 11386 2025-01-12 23:26:23.719251333   24130.000000  1.264017     0.359978
#
# [11387 rows x 7 columns]

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    roc_auc_score, classification_report,
    mean_absolute_error, mean_squared_error, r2_score
)

# 1) Load & clean
df = pd.read_csv('/content/drive/MyDrive/Data Analysis - Sample File.csv')
df = df.rename(columns={
    'Delivered_date': 'delivered_date',
    'Delivered Qty': 'delivered_qty',
    'Redistribution Value': 'spend'
})
df['delivered_date'] = pd.to_datetime(df['delivered_date'], errors='coerce', dayfirst=True)
df['spend'] = df['spend'].str.replace(',', '').astype(float)
df = df[df['delivered_qty'] > 0] \
       .sort_values(['Customer_Phone','SKU_Code','delivered_date'])

# 2) Features & targets
df['prev_date'] = df.groupby(['Customer_Phone','SKU_Code'])['delivered_date'].shift(1)
df['recency_days'] = (df['delivered_date'] - df['prev_date']).dt.days.fillna(-1)
df['cum_freq']      = df.groupby(['Customer_Phone','SKU_Code']).cumcount()
df['cum_spend']     = df.groupby(['Customer_Phone','SKU_Code'])['spend'].cumsum() - df['spend']
df['avg_spend_past']= df['cum_spend'] / df['cum_freq'].replace(0,1)
df['cum_qty']       = df.groupby(['Customer_Phone','SKU_Code'])['delivered_qty'].cumsum() - df['delivered_qty']
df['avg_qty_past']  = df['cum_qty'] / df['cum_freq'].replace(0,1)

df['next_date']  = df.groupby(['Customer_Phone','SKU_Code'])['delivered_date'].shift(-1)
df['next_days']  = (df['next_date'] - df['delivered_date']).dt.days
df['next_spend']= df.groupby(['Customer_Phone','SKU_Code'])['spend'].shift(-1)
df['next_qty']  = df.groupby(['Customer_Phone','SKU_Code'])['delivered_qty'].shift(-1)
df['y_buy']     = df['next_days'].notnull().astype(int)

le_sku = LabelEncoder().fit(df['SKU_Code'])
df['sku_enc'] = le_sku.transform(df['SKU_Code'])

features = ['recency_days','cum_freq','avg_spend_past','avg_qty_past','sku_enc']

# 3) Train/test split for classifier
X_clf = df[features]
y_clf = df['y_buy']
Xc_train, Xc_test, yc_train, yc_test = train_test_split(
    X_clf, y_clf, test_size=0.2, random_state=42
)

clf = RandomForestClassifier(n_estimators=20, random_state=42)
clf.fit(Xc_train, yc_train)

# 4) Eval classifier
probs = clf.predict_proba(Xc_test)[:,1]
preds = clf.predict(Xc_test)

print("=== CLASSIFIER METRICS ===")
print("ROC-AUC:", roc_auc_score(yc_test, probs))
print(classification_report(yc_test, preds))

# 5) Prepare train/test for regressors (only positive samples)
df_reg = df[df['y_buy']==1].dropna(subset=['next_days','next_spend','next_qty'])
Xr = df_reg[features]
yd = df_reg['next_days']
ys = df_reg['next_spend']
yq = df_reg['next_qty']

Xr_train, Xr_test, yd_train, yd_test, ys_train, ys_test, yq_train, yq_test = train_test_split(
    Xr, yd, ys, yq, test_size=0.2, random_state=42
)

# 6) Train regressors
reg_days  = RandomForestRegressor(n_estimators=20, random_state=42).fit(Xr_train, yd_train)
reg_spend = RandomForestRegressor(n_estimators=20, random_state=42).fit(Xr_train, ys_train)
reg_qty   = RandomForestRegressor(n_estimators=20, random_state=42).fit(Xr_train, yq_train)

# 7) Eval regressors
print("\n=== REGRESSOR METRICS ===")
for name, y_true, model in [
    ("Next-Days", yd_test, reg_days),
    ("Spend",     ys_test, reg_spend),
    ("Quantity",  yq_test, reg_qty)
]:
    y_pred = model.predict(Xr_test)
    print(f"\n-- {name} --")
    print(" MAE :", mean_absolute_error(y_true, y_pred))
    print(" RMSE:", np.sqrt(mean_squared_error(y_true, y_pred)))
    print(" R2  :", r2_score(y_true, y_pred))

# 8) (Optional) Continue with your prediction & top-3 extraction…

pred_df = results[['Customer_Phone', 'SKU_Code', 'last_purchase_date',
                   'pred_next_date', 'pred_spend', 'pred_qty', 'probability']]
pred_df
# Out:
# <ipython-input-21-686416891809>:13: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Data Analysis - Sample File.csv')
# === CLASSIFIER METRICS ===
# ROC-AUC: 0.7606125148882928
#               precision    recall  f1-score   support
#
#            0       0.68      0.67      0.67      9135
#            1       0.72      0.73      0.72     10649
#
#     accuracy                           0.70     19784
#    macro avg       0.70      0.70      0.70     19784
# weighted avg       0.70      0.70      0.70     19784
#
#
# === REGRESSOR METRICS ===
#
# -- Next-Days --
#  MAE : 17.539359457817106
#  RMSE: 24.46585274359179
#  R2  : 0.060901208560988795
#
# -- Spend --
#  MAE : 34471.54450148744
#  RMSE: 93288.74551944884
#  R2  : 0.13613760968158928
#
# -- Quantity --
#  MAE : 2.4408128650588745
#  RMSE: 6.661168013613155
#  R2  : 0.14571210337317997
#        Customer_Phone  SKU_Code last_purchase_date  \
# 0          7010009941  10002871         2024-11-28
# 1          7010009941  10002849         2024-10-03
# 2          7010009941  10002857         2025-01-02
# 3          7010147753  10002957         2024-11-28
# 4          7010147753  10002835         2024-09-09
# ...               ...       ...                ...
# 11382      9167401267  10003376         2025-01-07
# 11383      9167401267  10002861         2024-10-14
# 11384      9169810564  10000533         2024-11-21
# 11385      9169810564  10002844         2024-12-19
# 11386      9169810564  10002843         2024-12-19
#
#                      pred_next_date     pred_spend  pred_qty  probability
# 0     2024-12-14 14:43:34.718568473   20050.000000  1.023395     0.100000
# 1     2024-10-12 07:12:00.000000000   20607.500000  1.000000     0.000000
# 2     2025-01-23 22:48:00.000000000   24190.000000  1.100000     0.000000
# 3     2024-12-13 16:37:41.149746635  183629.656963  1.617399     0.304423
# 4     2024-10-08 04:18:16.049154156   23242.500000  1.159429     0.251098
# ...                             ...            ...       ...          ...
# 11382 2025-01-31 03:24:24.302564821   19850.000000  1.122391     0.273278
# 11383 2024-10-30 01:06:11.361857771   20000.000000  1.020956     0.173211
# 11384 2024-12-20 14:35:09.733016040   90317.778957  5.902993     0.428003
# 11385 2025-01-09 21:47:19.415802937   24130.000000  1.310417     0.374679
# 11386 2025-01-12 23:26:23.719251333   24130.000000  1.264017     0.359978
#
# [11387 rows x 7 columns]

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.15.2)

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from xgboost import XGBClassifier, XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    roc_auc_score, classification_report,
    mean_absolute_error, mean_squared_error, r2_score
)

# 1) Load & clean
df = pd.read_csv('/content/drive/MyDrive/Data Analysis - Sample File.csv')
df = df.rename(columns={
    'Delivered_date': 'delivered_date',
    'Delivered Qty': 'delivered_qty',
    'Redistribution Value': 'spend'
})
df['delivered_date'] = pd.to_datetime(
    df['delivered_date'], errors='coerce', dayfirst=True
)
df['spend'] = df['spend'].str.replace(',', '').astype(float)
df = df[df['delivered_qty'] > 0].sort_values(
    ['Customer_Phone','SKU_Code','delivered_date']
)

# 2) Feature engineering & targets
df['prev_date'] = df.groupby(['Customer_Phone','SKU_Code'])['delivered_date'].shift(1)
df['recency_days'] = (df['delivered_date'] - df['prev_date']).dt.days.fillna(-1)
df['cum_freq']   = df.groupby(['Customer_Phone','SKU_Code']).cumcount()
df['cum_spend']  = df.groupby(['Customer_Phone','SKU_Code'])['spend'].cumsum() - df['spend']
df['avg_spend_past'] = df['cum_spend'] / df['cum_freq'].replace(0,1)
df['cum_qty']    = df.groupby(['Customer_Phone','SKU_Code'])['delivered_qty'].cumsum() - df['delivered_qty']
df['avg_qty_past']= df['cum_qty'] / df['cum_freq'].replace(0,1)

df['next_date']   = df.groupby(['Customer_Phone','SKU_Code'])['delivered_date'].shift(-1)
df['next_days']   = (df['next_date'] - df['delivered_date']).dt.days
df['next_spend']  = df.groupby(['Customer_Phone','SKU_Code'])['spend'].shift(-1)
df['next_qty']    = df.groupby(['Customer_Phone','SKU_Code'])['delivered_qty'].shift(-1)
df['y_buy']       = df['next_days'].notnull().astype(int)

le = LabelEncoder().fit(df['SKU_Code'])
df['sku_enc'] = le.transform(df['SKU_Code'])

features = ['recency_days','cum_freq','avg_spend_past','avg_qty_past','sku_enc']

# 3) Classifier train/test
Xc = df[features]
yc = df['y_buy']
Xc_train, Xc_test, yc_train, yc_test = train_test_split(
    Xc, yc, test_size=0.2, random_state=42
)

clf = XGBClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=6,
    use_label_encoder=False,
    eval_metric='logloss',
    random_state=42
)
clf.fit(Xc_train, yc_train)

# 4) Classifier eval
probs = clf.predict_proba(Xc_test)[:,1]
preds = clf.predict(Xc_test)
print("ROC-AUC:", roc_auc_score(yc_test, probs))
print(classification_report(yc_test, preds))

# 5) Regressor train/test on positive samples
df_reg = df[df['y_buy']==1].dropna(subset=['next_days','next_spend','next_qty'])
Xr = df_reg[features]
yr_days  = df_reg['next_days']
yr_spend = df_reg['next_spend']
yr_qty   = df_reg['next_qty']

Xr_train, Xr_test, yd_train, yd_test, ys_train, ys_test, yq_train, yq_test = train_test_split(
    Xr, yr_days, yr_spend, yr_qty, test_size=0.2, random_state=42
)

reg_days = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=6, random_state=42)
reg_spend= XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=6, random_state=42)
reg_qty  = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=6, random_state=42)

reg_days.fit(Xr_train, yd_train)
reg_spend.fit(Xr_train, ys_train)
reg_qty.fit(Xr_train, yq_train)

# 6) Regressor eval
for name, y_true, model in [
    ("Next-Days", yd_test, reg_days),
    ("Spend",     ys_test, reg_spend),
    ("Quantity",  yq_test, reg_qty)
]:
    y_pred = model.predict(Xr_test)
    print(f"\n-- {name} --")
    print(" MAE :", mean_absolute_error(y_true, y_pred))
    print(" RMSE:", np.sqrt(mean_squared_error(y_true, y_pred)))
    print(" R2  :", r2_score(y_true, y_pred))

# 7) Final top-3 extraction remains the same…

pred_df = results[['Customer_Phone', 'SKU_Code', 'last_purchase_date',
                   'pred_next_date', 'pred_spend', 'pred_qty', 'probability']]
pred_df
# Out:
# <ipython-input-22-3c90999cbc7c>:13: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Data Analysis - Sample File.csv')
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [16:16:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ROC-AUC: 0.7749623851038586
#               precision    recall  f1-score   support
#
#            0       0.70      0.65      0.68      9135
#            1       0.72      0.76      0.74     10649
#
#     accuracy                           0.71     19784
#    macro avg       0.71      0.71      0.71     19784
# weighted avg       0.71      0.71      0.71     19784
#
#
# -- Next-Days --
#  MAE : 16.67879671712265
#  RMSE: 23.363590977426714
#  R2  : 0.14361361188055288
#
# -- Spend --
#  MAE : 33056.48375879503
#  RMSE: 93532.5650345117
#  R2  : 0.13161612630881137
#
# -- Quantity --
#  MAE : 2.3263789571514644
#  RMSE: 6.8436803690160115
#  R2  : 0.0982567228440826
#        Customer_Phone  SKU_Code last_purchase_date  \
# 0          7010009941  10002871         2024-11-28
# 1          7010009941  10002849         2024-10-03
# 2          7010009941  10002857         2025-01-02
# 3          7010147753  10002957         2024-11-28
# 4          7010147753  10002835         2024-09-09
# ...               ...       ...                ...
# 11382      9167401267  10003376         2025-01-07
# 11383      9167401267  10002861         2024-10-14
# 11384      9169810564  10000533         2024-11-21
# 11385      9169810564  10002844         2024-12-19
# 11386      9169810564  10002843         2024-12-19
#
#                      pred_next_date     pred_spend  pred_qty  probability
# 0     2024-12-14 14:43:34.718568473   20050.000000  1.023395     0.100000
# 1     2024-10-12 07:12:00.000000000   20607.500000  1.000000     0.000000
# 2     2025-01-23 22:48:00.000000000   24190.000000  1.100000     0.000000
# 3     2024-12-13 16:37:41.149746635  183629.656963  1.617399     0.304423
# 4     2024-10-08 04:18:16.049154156   23242.500000  1.159429     0.251098
# ...                             ...            ...       ...          ...
# 11382 2025-01-31 03:24:24.302564821   19850.000000  1.122391     0.273278
# 11383 2024-10-30 01:06:11.361857771   20000.000000  1.020956     0.173211
# 11384 2024-12-20 14:35:09.733016040   90317.778957  5.902993     0.428003
# 11385 2025-01-09 21:47:19.415802937   24130.000000  1.310417     0.374679
# 11386 2025-01-12 23:26:23.719251333   24130.000000  1.264017     0.359978
#
# [11387 rows x 7 columns]

# %%
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in /usr/local/lib/python3.11/dist-packages (1.1.6)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from prophet) (1.2.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.11/dist-packages (from prophet) (2.0.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from prophet) (3.10.0)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from prophet) (2.2.2)
# Requirement already satisfied: holidays<1,>=0.25 in /usr/local/lib/python3.11/dist-packages (from prophet) (0.71)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.11/dist-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from prophet) (6.5.2)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.17.0)

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from xgboost import XGBClassifier, XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    roc_auc_score, classification_report,
    mean_absolute_error, mean_squared_error, r2_score
)
from prophet import Prophet
from IPython.display import display

# 3) Load & clean
df = pd.read_csv('/content/drive/MyDrive/Data Analysis - Sample File.csv')
df = df.rename(columns={
    'Delivered_date': 'delivered_date',
    'Delivered Qty': 'delivered_qty',
    'Redistribution Value': 'spend'
})
df['delivered_date'] = pd.to_datetime(df['delivered_date'], errors='coerce', dayfirst=True)
df['spend'] = df['spend'].str.replace(',', '').astype(float)
df = df[df['delivered_qty'] > 0].sort_values(['Customer_Phone','SKU_Code','delivered_date'])

# 4) Feature engineering & targets
df['prev_date'] = df.groupby(['Customer_Phone','SKU_Code'])['delivered_date'].shift(1)
df['recency_days'] = (df['delivered_date'] - df['prev_date']).dt.days.fillna(-1)
df['cum_freq']   = df.groupby(['Customer_Phone','SKU_Code']).cumcount()
df['cum_spend']  = df.groupby(['Customer_Phone','SKU_Code'])['spend'].cumsum() - df['spend']
df['avg_spend_past'] = df['cum_spend'] / df['cum_freq'].replace(0,1)
df['cum_qty']    = df.groupby(['Customer_Phone','SKU_Code'])['delivered_qty'].cumsum() - df['delivered_qty']
df['avg_qty_past']= df['cum_qty'] / df['cum_freq'].replace(0,1)

df['next_date']  = df.groupby(['Customer_Phone','SKU_Code'])['delivered_date'].shift(-1)
df['next_days']  = (df['next_date'] - df['delivered_date']).dt.days
df['next_spend'] = df.groupby(['Customer_Phone','SKU_Code'])['spend'].shift(-1)
df['next_qty']   = df.groupby(['Customer_Phone','SKU_Code'])['delivered_qty'].shift(-1)
df['y_buy']      = df['next_days'].notnull().astype(int)

le = LabelEncoder().fit(df['SKU_Code'])
df['sku_enc'] = le.transform(df['SKU_Code'])

features = ['recency_days','cum_freq','avg_spend_past','avg_qty_past','sku_enc']

# 5) Classifier
Xc_train, Xc_test, yc_train, yc_test = train_test_split(
    df[features], df['y_buy'], test_size=0.2, random_state=42
)
clf = XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=6, eval_metric='logloss', random_state=42)
clf.fit(Xc_train, yc_train)
probs = clf.predict_proba(Xc_test)[:,1]
preds = clf.predict(Xc_test)
print("=== CLASSIFIER METRICS ===")
print("ROC-AUC:", roc_auc_score(yc_test, probs))
print(classification_report(yc_test, preds))

# 6) Time-series for next purchase date
ts_preds = []
for (cust, sku), grp in df.groupby(['Customer_Phone','SKU_Code']):
    ts = grp[['delivered_date']].rename(columns={'delivered_date':'ds'})
    ts['y'] = 1
    ts = ts.set_index('ds').resample('D').sum().reset_index()
    if len(ts) < 3: continue
    m = Prophet(daily_seasonality=False, weekly_seasonality=True, yearly_seasonality=False)
    m.fit(ts)
    future = m.make_future_dataframe(periods=60)
    fcst = m.predict(future)
    next_day = fcst.loc[fcst['yhat']>0.5,'ds']
    if not next_day.empty:
        ts_preds.append({'Customer_Phone':cust,'SKU_Code':sku,'ts_pred_next_date':next_day.min()})
ts_df = pd.DataFrame(ts_preds)

# 7) Merge TS preds
latest = df.groupby(['Customer_Phone','SKU_Code']).last().reset_index()
latest = latest.merge(ts_df, on=['Customer_Phone','SKU_Code'], how='left')
latest['last_purchase_date'] = latest['delivered_date']

# 8) Regression split with non-null targets
df_reg = df[df['y_buy']==1].dropna(subset=['next_spend','next_qty'])
Xr = df_reg[features]
ys = df_reg['next_spend']
yq = df_reg['next_qty']
Xr_train, Xr_test, ys_train, ys_test, yq_train, yq_test = train_test_split(
    Xr, ys, yq, test_size=0.2, random_state=42
)

reg_spend = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=6, random_state=42)
reg_qty   = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=6, random_state=42)
reg_spend.fit(Xr_train, ys_train)
reg_qty.fit(Xr_train, yq_train)

# 9) Reg metrics
print("=== REGRESSOR METRICS ===")
print("-- Spend -- MAE:", mean_absolute_error(ys_test, reg_spend.predict(Xr_test)),
      "RMSE:", np.sqrt(mean_squared_error(ys_test, reg_spend.predict(Xr_test))),
      "R2:", r2_score(ys_test, reg_spend.predict(Xr_test)))
print("-- Qty   -- MAE:", mean_absolute_error(yq_test, reg_qty.predict(Xr_test)),
      "RMSE:", np.sqrt(mean_squared_error(yq_test, reg_qty.predict(Xr_test))),
      "R2:", r2_score(yq_test, reg_qty.predict(Xr_test)))

# 10) Top-3 extraction
latest['probability']   = clf.predict_proba(latest[features])[:,1]
latest['pred_spend']    = reg_spend.predict(latest[features])
latest['pred_qty']      = reg_qty.predict(latest[features])
latest['pred_next_date']= latest['ts_pred_next_date'].fillna(
    latest['last_purchase_date'] + pd.to_timedelta(latest['next_days'].fillna(0),'D')
)
results = (latest.sort_values(['Customer_Phone','probability'],ascending=[True,False])
            .groupby('Customer_Phone').head(3).reset_index(drop=True))
display(results[['Customer_Phone','SKU_Code','last_purchase_date','pred_next_date','pred_spend','pred_qty','probability']].head(10))
# Out:
# <ipython-input-25-6d8a9ae78391>:15: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Data Analysis - Sample File.csv')
# === CLASSIFIER METRICS ===
# ROC-AUC: 0.7749623851038586
#               precision    recall  f1-score   support
#
#            0       0.70      0.65      0.68      9135
#            1       0.72      0.76      0.74     10649
#
#     accuracy                           0.71     19784
#    macro avg       0.71      0.71      0.71     19784
# weighted avg       0.71      0.71      0.71     19784
# Streaming output truncated to the last 5000 lines.
# INFO:prophet:n_changepoints greater than number of observations. Using 4.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/miwrgxlt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/yic0jjh0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95724', 'data', 'file=/tmp/tmpiugaoh_1/miwrgxlt.json', 'init=/tmp/tmpiugaoh_1/yic0jjh0.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modeleal787i0/prophet_model-20250504195653.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 24.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/l4f6lqwv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/7wrcmqqm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63730', 'data', 'file=/tmp/tmpiugaoh_1/l4f6lqwv.json', 'init=/tmp/tmpiugaoh_1/7wrcmqqm.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelgx60br0n/prophet_model-20250504195653.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/5cho5rqz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/0b16_y12.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96875', 'data', 'file=/tmp/tmpiugaoh_1/5cho5rqz.json', 'init=/tmp/tmpiugaoh_1/0b16_y12.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelkvueppnv/prophet_model-20250504195653.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/n5b70_1m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/etc7ie_3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84176', 'data', 'file=/tmp/tmpiugaoh_1/n5b70_1m.json', 'init=/tmp/tmpiugaoh_1/etc7ie_3.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model9edju9ge/prophet_model-20250504195654.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/dt0q9mo6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/h27avdp7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40890', 'data', 'file=/tmp/tmpiugaoh_1/dt0q9mo6.json', 'init=/tmp/tmpiugaoh_1/h27avdp7.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelkro2q5vj/prophet_model-20250504195654.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:56:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/9fmjjplv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/vmcbez9q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20293', 'data', 'file=/tmp/tmpiugaoh_1/9fmjjplv.json', 'init=/tmp/tmpiugaoh_1/vmcbez9q.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelwm_v89dc/prophet_model-20250504195654.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/jf6xxgat.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/5k0cc4zj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73705', 'data', 'file=/tmp/tmpiugaoh_1/jf6xxgat.json', 'init=/tmp/tmpiugaoh_1/5k0cc4zj.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model9dj6yi1d/prophet_model-20250504195655.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/0ns9bers.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/g_pw1_f8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83352', 'data', 'file=/tmp/tmpiugaoh_1/0ns9bers.json', 'init=/tmp/tmpiugaoh_1/g_pw1_f8.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelvv2otwcx/prophet_model-20250504195655.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 20.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/g7lukk7o.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/8up21fd8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30006', 'data', 'file=/tmp/tmpiugaoh_1/g7lukk7o.json', 'init=/tmp/tmpiugaoh_1/8up21fd8.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modeljeinm51n/prophet_model-20250504195655.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/b7sllj7x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/i07q9m0t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20881', 'data', 'file=/tmp/tmpiugaoh_1/b7sllj7x.json', 'init=/tmp/tmpiugaoh_1/i07q9m0t.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model084cb8fl/prophet_model-20250504195655.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:56:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/wlotr38f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/rvl139az.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71738', 'data', 'file=/tmp/tmpiugaoh_1/wlotr38f.json', 'init=/tmp/tmpiugaoh_1/rvl139az.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model9x3o5_w2/prophet_model-20250504195656.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 11.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/mb_2ur6h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/o3j4syv_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68996', 'data', 'file=/tmp/tmpiugaoh_1/mb_2ur6h.json', 'init=/tmp/tmpiugaoh_1/o3j4syv_.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelwjbtjzom/prophet_model-20250504195656.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/hghohgph.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/c_htu8cx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6338', 'data', 'file=/tmp/tmpiugaoh_1/hghohgph.json', 'init=/tmp/tmpiugaoh_1/c_htu8cx.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modeld3hltcwp/prophet_model-20250504195656.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/2f8bokb7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/i1f1969c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24238', 'data', 'file=/tmp/tmpiugaoh_1/2f8bokb7.json', 'init=/tmp/tmpiugaoh_1/i1f1969c.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modeljvd0c7fc/prophet_model-20250504195657.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/dcp_eyp6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/rnev8icn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77998', 'data', 'file=/tmp/tmpiugaoh_1/dcp_eyp6.json', 'init=/tmp/tmpiugaoh_1/rnev8icn.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelrpcw5jb_/prophet_model-20250504195657.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/f9rhw3jg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/1hvdshbu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93151', 'data', 'file=/tmp/tmpiugaoh_1/f9rhw3jg.json', 'init=/tmp/tmpiugaoh_1/1hvdshbu.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelkbxfuek6/prophet_model-20250504195657.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/q9f67v54.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/7zmhdlk8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88726', 'data', 'file=/tmp/tmpiugaoh_1/q9f67v54.json', 'init=/tmp/tmpiugaoh_1/7zmhdlk8.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelu8592fht/prophet_model-20250504195658.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/lbnw2bpq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/l4d_95gk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20863', 'data', 'file=/tmp/tmpiugaoh_1/lbnw2bpq.json', 'init=/tmp/tmpiugaoh_1/l4d_95gk.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelr631ynde/prophet_model-20250504195658.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/stwipho9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/uk124q0c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57169', 'data', 'file=/tmp/tmpiugaoh_1/stwipho9.json', 'init=/tmp/tmpiugaoh_1/uk124q0c.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelm4faqrck/prophet_model-20250504195658.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:56:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/bsf91x31.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/pwxrfl01.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19277', 'data', 'file=/tmp/tmpiugaoh_1/bsf91x31.json', 'init=/tmp/tmpiugaoh_1/pwxrfl01.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelyp9bqmwj/prophet_model-20250504195658.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 10.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/t80wg4_c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/bzviuahf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79321', 'data', 'file=/tmp/tmpiugaoh_1/t80wg4_c.json', 'init=/tmp/tmpiugaoh_1/bzviuahf.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modely3kdv55t/prophet_model-20250504195659.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/fvdkvh3n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/c8tigx12.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31198', 'data', 'file=/tmp/tmpiugaoh_1/fvdkvh3n.json', 'init=/tmp/tmpiugaoh_1/c8tigx12.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelloch4ubu/prophet_model-20250504195659.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:56:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/jdll2k2l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/zlaa5v2v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8531', 'data', 'file=/tmp/tmpiugaoh_1/jdll2k2l.json', 'init=/tmp/tmpiugaoh_1/zlaa5v2v.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model7mqxb8kl/prophet_model-20250504195659.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/w6stqaqh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/h6oc0kwt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43888', 'data', 'file=/tmp/tmpiugaoh_1/w6stqaqh.json', 'init=/tmp/tmpiugaoh_1/h6oc0kwt.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelwgy2l51s/prophet_model-20250504195659.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:56:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/2pqh33xi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/zqwdpawe.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22215', 'data', 'file=/tmp/tmpiugaoh_1/2pqh33xi.json', 'init=/tmp/tmpiugaoh_1/zqwdpawe.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelbogle93v/prophet_model-20250504195659.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:56:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/x1ip1njo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/z3r227rc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4874', 'data', 'file=/tmp/tmpiugaoh_1/x1ip1njo.json', 'init=/tmp/tmpiugaoh_1/z3r227rc.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modeld1rqr2hg/prophet_model-20250504195700.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:57:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/k9lbuq8a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/8_jogurr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53947', 'data', 'file=/tmp/tmpiugaoh_1/k9lbuq8a.json', 'init=/tmp/tmpiugaoh_1/8_jogurr.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modela2wfy0ng/prophet_model-20250504195700.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 4.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/e2qkqph7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/j07yiawq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20851', 'data', 'file=/tmp/tmpiugaoh_1/e2qkqph7.json', 'init=/tmp/tmpiugaoh_1/j07yiawq.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_models30u1u11/prophet_model-20250504195700.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/l82_jm0j.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/odl9tn1p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72678', 'data', 'file=/tmp/tmpiugaoh_1/l82_jm0j.json', 'init=/tmp/tmpiugaoh_1/odl9tn1p.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelwjz13nh1/prophet_model-20250504195700.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/8oq7rp51.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/_vy0crp1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4538', 'data', 'file=/tmp/tmpiugaoh_1/8oq7rp51.json', 'init=/tmp/tmpiugaoh_1/_vy0crp1.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model1ae7n__e/prophet_model-20250504195701.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 15.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/jo8ccull.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/9hojldwn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54498', 'data', 'file=/tmp/tmpiugaoh_1/jo8ccull.json', 'init=/tmp/tmpiugaoh_1/9hojldwn.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelzet3uixf/prophet_model-20250504195701.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/pruv1rte.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/3sy0sff5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77677', 'data', 'file=/tmp/tmpiugaoh_1/pruv1rte.json', 'init=/tmp/tmpiugaoh_1/3sy0sff5.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelixmgfet2/prophet_model-20250504195701.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 18.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/bz9fn79k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/iwep41qw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3682', 'data', 'file=/tmp/tmpiugaoh_1/bz9fn79k.json', 'init=/tmp/tmpiugaoh_1/iwep41qw.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelvbolz_sr/prophet_model-20250504195701.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/jnzejay1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/4m_62phd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33271', 'data', 'file=/tmp/tmpiugaoh_1/jnzejay1.json', 'init=/tmp/tmpiugaoh_1/4m_62phd.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modeld24iar4_/prophet_model-20250504195702.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:57:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 12.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/7t6fsk1a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/qvkjmq0z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73110', 'data', 'file=/tmp/tmpiugaoh_1/7t6fsk1a.json', 'init=/tmp/tmpiugaoh_1/qvkjmq0z.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelpk0hss6v/prophet_model-20250504195702.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/gr_eq261.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/wgj_fbjb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71210', 'data', 'file=/tmp/tmpiugaoh_1/gr_eq261.json', 'init=/tmp/tmpiugaoh_1/wgj_fbjb.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model3hq2jn4k/prophet_model-20250504195702.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/zdu41em5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/yygn1n3i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82476', 'data', 'file=/tmp/tmpiugaoh_1/zdu41em5.json', 'init=/tmp/tmpiugaoh_1/yygn1n3i.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelfsh7gjcj/prophet_model-20250504195702.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/0wb672x8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/ibj6jhby.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17149', 'data', 'file=/tmp/tmpiugaoh_1/0wb672x8.json', 'init=/tmp/tmpiugaoh_1/ibj6jhby.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model4jmxyjp9/prophet_model-20250504195702.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:57:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 22.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/ca3333ja.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/t5tctmre.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90294', 'data', 'file=/tmp/tmpiugaoh_1/ca3333ja.json', 'init=/tmp/tmpiugaoh_1/t5tctmre.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelejeq_o3z/prophet_model-20250504195703.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/f_xosf7h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/s2i5247y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78884', 'data', 'file=/tmp/tmpiugaoh_1/f_xosf7h.json', 'init=/tmp/tmpiugaoh_1/s2i5247y.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelbgr0k3ao/prophet_model-20250504195703.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/0to5ofux.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/mck_i6vk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91307', 'data', 'file=/tmp/tmpiugaoh_1/0to5ofux.json', 'init=/tmp/tmpiugaoh_1/mck_i6vk.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelqic1cp0x/prophet_model-20250504195703.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:57:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/kanoxlw1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/gnfat7sz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39158', 'data', 'file=/tmp/tmpiugaoh_1/kanoxlw1.json', 'init=/tmp/tmpiugaoh_1/gnfat7sz.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modeltmp9mo93/prophet_model-20250504195703.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 11.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/rkmp0w4t.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/m7d9o3c6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34040', 'data', 'file=/tmp/tmpiugaoh_1/rkmp0w4t.json', 'init=/tmp/tmpiugaoh_1/m7d9o3c6.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelw31p6new/prophet_model-20250504195703.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/q3uctn3v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/d85wuwzs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83623', 'data', 'file=/tmp/tmpiugaoh_1/q3uctn3v.json', 'init=/tmp/tmpiugaoh_1/d85wuwzs.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model92da_vsr/prophet_model-20250504195704.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:57:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/v9v7j_nf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/5zewa8bg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21253', 'data', 'file=/tmp/tmpiugaoh_1/v9v7j_nf.json', 'init=/tmp/tmpiugaoh_1/5zewa8bg.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model9difwfm1/prophet_model-20250504195704.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 19.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/kwyw1urg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/the5ie48.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34492', 'data', 'file=/tmp/tmpiugaoh_1/kwyw1urg.json', 'init=/tmp/tmpiugaoh_1/the5ie48.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelrcl6wmkd/prophet_model-20250504195704.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/449pz58d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/lk3q_fpg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=97325', 'data', 'file=/tmp/tmpiugaoh_1/449pz58d.json', 'init=/tmp/tmpiugaoh_1/lk3q_fpg.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modely8ddc4s7/prophet_model-20250504195704.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/c2x19eeh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/5tdibwv8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44742', 'data', 'file=/tmp/tmpiugaoh_1/c2x19eeh.json', 'init=/tmp/tmpiugaoh_1/5tdibwv8.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelmj6aic4g/prophet_model-20250504195705.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/4f_p634x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/ds2cjmhr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48845', 'data', 'file=/tmp/tmpiugaoh_1/4f_p634x.json', 'init=/tmp/tmpiugaoh_1/ds2cjmhr.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelmefr3cp1/prophet_model-20250504195705.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:57:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/mc7qggxg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/utx3to1i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38882', 'data', 'file=/tmp/tmpiugaoh_1/mc7qggxg.json', 'init=/tmp/tmpiugaoh_1/utx3to1i.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model_saek8xa/prophet_model-20250504195705.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/july1y3n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/0wfumruh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70834', 'data', 'file=/tmp/tmpiugaoh_1/july1y3n.json', 'init=/tmp/tmpiugaoh_1/0wfumruh.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model8872fm2y/prophet_model-20250504195705.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/hj5fqncg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/2kvsdw_8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8594', 'data', 'file=/tmp/tmpiugaoh_1/hj5fqncg.json', 'init=/tmp/tmpiugaoh_1/2kvsdw_8.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modellt8dejxk/prophet_model-20250504195706.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:57:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/gl7x5q9e.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/ethglter.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14426', 'data', 'file=/tmp/tmpiugaoh_1/gl7x5q9e.json', 'init=/tmp/tmpiugaoh_1/ethglter.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modeleu3szm8v/prophet_model-20250504195706.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:57:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/cp5uko0u.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/cj7eo_az.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40691', 'data', 'file=/tmp/tmpiugaoh_1/cp5uko0u.json', 'init=/tmp/tmpiugaoh_1/cj7eo_az.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelyrpcnkis/prophet_model-20250504195706.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:57:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/lflpuk51.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/p857bc5m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43679', 'data', 'file=/tmp/tmpiugaoh_1/lflpuk51.json', 'init=/tmp/tmpiugaoh_1/p857bc5m.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modell48a42mo/prophet_model-20250504195706.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:57:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 5.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/ciw9ne53.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/a3aq_2kk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1440', 'data', 'file=/tmp/tmpiugaoh_1/ciw9ne53.json', 'init=/tmp/tmpiugaoh_1/a3aq_2kk.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelczok6hru/prophet_model-20250504195706.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 7.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/_ytzxcdc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/2fy0i3rk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77605', 'data', 'file=/tmp/tmpiugaoh_1/_ytzxcdc.json', 'init=/tmp/tmpiugaoh_1/2fy0i3rk.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model2cq4be27/prophet_model-20250504195711.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 5.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/eoqtaeor.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/y6igl7az.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13059', 'data', 'file=/tmp/tmpiugaoh_1/eoqtaeor.json', 'init=/tmp/tmpiugaoh_1/y6igl7az.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelwiryjooz/prophet_model-20250504195711.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/wh_7qm2v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/cbfi7xdl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67360', 'data', 'file=/tmp/tmpiugaoh_1/wh_7qm2v.json', 'init=/tmp/tmpiugaoh_1/cbfi7xdl.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelz2l_1sxh/prophet_model-20250504195712.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:57:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/xkiobrjd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/2dvxf6ro.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77663', 'data', 'file=/tmp/tmpiugaoh_1/xkiobrjd.json', 'init=/tmp/tmpiugaoh_1/2dvxf6ro.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelpthd0e9v/prophet_model-20250504195713.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:57:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:57:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 24.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/hu7o367y.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/625x0o85.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77195', 'data', 'file=/tmp/tmpiugaoh_1/hu7o367y.json', 'init=/tmp/tmpiugaoh_1/625x0o85.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelus_kz0zb/prophet_model-20250504195713.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# ...
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85531', 'data', 'file=/tmp/tmpiugaoh_1/aibqhoic.json', 'init=/tmp/tmpiugaoh_1/__h3x39y.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model9_16mjjm/prophet_model-20250504195937.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:59:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 12.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/_5oq76ur.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/gyht40yf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69826', 'data', 'file=/tmp/tmpiugaoh_1/_5oq76ur.json', 'init=/tmp/tmpiugaoh_1/gyht40yf.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelrsep0_ju/prophet_model-20250504195937.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:59:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/l2gch0hg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/yum0tv3g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98384', 'data', 'file=/tmp/tmpiugaoh_1/l2gch0hg.json', 'init=/tmp/tmpiugaoh_1/yum0tv3g.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelo_dq4mwh/prophet_model-20250504195937.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:59:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/jxw5ublx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/218agt06.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5142', 'data', 'file=/tmp/tmpiugaoh_1/jxw5ublx.json', 'init=/tmp/tmpiugaoh_1/218agt06.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_models5srjkz4/prophet_model-20250504195938.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:59:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/8lhc1mob.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/hrc89ooo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18803', 'data', 'file=/tmp/tmpiugaoh_1/8lhc1mob.json', 'init=/tmp/tmpiugaoh_1/hrc89ooo.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model3qpkpce7/prophet_model-20250504195938.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:59:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/skq__vol.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/r1iooree.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43721', 'data', 'file=/tmp/tmpiugaoh_1/skq__vol.json', 'init=/tmp/tmpiugaoh_1/r1iooree.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelved3zew0/prophet_model-20250504195939.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:59:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/u271fhx6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/w274zr7a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11327', 'data', 'file=/tmp/tmpiugaoh_1/u271fhx6.json', 'init=/tmp/tmpiugaoh_1/w274zr7a.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelae_wib_9/prophet_model-20250504195939.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:59:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/w2ca0lea.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/nyb5mbyd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56709', 'data', 'file=/tmp/tmpiugaoh_1/w2ca0lea.json', 'init=/tmp/tmpiugaoh_1/nyb5mbyd.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelx5shzlnk/prophet_model-20250504195939.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:59:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/_ltloqxh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/l880vcz6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29058', 'data', 'file=/tmp/tmpiugaoh_1/_ltloqxh.json', 'init=/tmp/tmpiugaoh_1/l880vcz6.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model5mpdvjfy/prophet_model-20250504195939.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:59:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 24.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/ru6disnv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/s8zinhsp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54513', 'data', 'file=/tmp/tmpiugaoh_1/ru6disnv.json', 'init=/tmp/tmpiugaoh_1/s8zinhsp.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelwg6sg9n9/prophet_model-20250504195940.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:59:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/rutvl5yt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/pgm751jp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38736', 'data', 'file=/tmp/tmpiugaoh_1/rutvl5yt.json', 'init=/tmp/tmpiugaoh_1/pgm751jp.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modeli2rgpbpu/prophet_model-20250504195940.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:59:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 17.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/00w45i9z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/xjgcswxg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25780', 'data', 'file=/tmp/tmpiugaoh_1/00w45i9z.json', 'init=/tmp/tmpiugaoh_1/xjgcswxg.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelpctx4p70/prophet_model-20250504195940.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:59:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 7.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/2e9r6vwq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/bw8qpo32.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49907', 'data', 'file=/tmp/tmpiugaoh_1/2e9r6vwq.json', 'init=/tmp/tmpiugaoh_1/bw8qpo32.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelq1o4es4r/prophet_model-20250504195940.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:59:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/04tsjuan.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/jthbovsg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89018', 'data', 'file=/tmp/tmpiugaoh_1/04tsjuan.json', 'init=/tmp/tmpiugaoh_1/jthbovsg.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modeli4u13gv4/prophet_model-20250504195940.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:59:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/hlzkipsr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/g3831r53.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56789', 'data', 'file=/tmp/tmpiugaoh_1/hlzkipsr.json', 'init=/tmp/tmpiugaoh_1/g3831r53.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelqi0ezvaf/prophet_model-20250504195940.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:59:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/hxjz8xfx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/aj2blpce.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94939', 'data', 'file=/tmp/tmpiugaoh_1/hxjz8xfx.json', 'init=/tmp/tmpiugaoh_1/aj2blpce.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_modelfg1htoyp/prophet_model-20250504195941.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:59:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 11.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/9zlk0vyo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/1m1garcg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10437', 'data', 'file=/tmp/tmpiugaoh_1/9zlk0vyo.json', 'init=/tmp/tmpiugaoh_1/1m1garcg.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model5vp3aj96/prophet_model-20250504195941.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:59:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/y067syxq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/zqg4gput.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64362', 'data', 'file=/tmp/tmpiugaoh_1/y067syxq.json', 'init=/tmp/tmpiugaoh_1/zqg4gput.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model_gtsnyhd/prophet_model-20250504195941.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:59:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/ady146lc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiugaoh_1/_64ipvom.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69792', 'data', 'file=/tmp/tmpiugaoh_1/ady146lc.json', 'init=/tmp/tmpiugaoh_1/_64ipvom.json', 'output', 'file=/tmp/tmpiugaoh_1/prophet_model6gryiwew/prophet_model-20250504195941.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:59:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:59:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# === REGRESSOR METRICS ===
# -- Spend -- MAE: 33056.48375879503 RMSE: 93532.5650345117 R2: 0.13161612630881137
# -- Qty   -- MAE: 2.3263789571514644 RMSE: 6.8436803690160115 R2: 0.0982567228440826
#    Customer_Phone  SKU_Code last_purchase_date pred_next_date    pred_spend  \
# 0      7010009941  10002849         2024-10-03     2024-11-21  27030.351562
# 1      7010009941  10002866         2024-12-26     2025-03-20  23784.468750
# 2      7010009941  10002857         2025-01-02     2025-04-03  23784.468750
# 3      7010147753  10002849         2024-10-16     2024-11-20  26422.642578
# 4      7010147753  10002832         2024-10-03     2024-11-09  34583.308594
# 5      7010147753  10002866         2024-09-11     2024-09-11  25418.720703
# 6      7010301833  10002832         2024-10-22     2024-12-01  76847.632812
# 7      7010301833  10002830         2024-10-22     2024-10-22  30868.351562
# 8      7010301833  10003376         2025-01-06     2024-12-24  52129.347656
# 9      7010572000  10000539         2024-10-23     2024-10-23  86765.750000
#
#    pred_qty  probability
# 0  1.361134     0.786555
# 1  1.203211     0.462454
# 2  1.180941     0.407207
# 3  1.321600     0.823764
# 4  1.710547     0.770259
# 5  1.346955     0.538113
# 6  5.201844     0.555498
# 7  1.604616     0.491128
# 8  2.648791     0.485204
# 9  6.205529     0.711128
